# %% [markdown]
# <a href="https://colab.research.google.com/github/hamchikan/hamchikan/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
print("hello world! and i'm a cyber security")
# Out:
# hello world! and i'm a cyber security
